# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import cv2
import urllib
import numpy as np
from os import path
from tqdm import tqdm
from utils import *
# Out:
# /Users/donald/anaconda3/envs/tf36/lib/python3.6/site-packages/skimage/viewer/__init__.py:6: UserWarning: Viewer requires Qt
#   warn('Viewer requires Qt')

# %%
img_dir = 'http://www.utdallas.edu/~axn112530/cs6375/unsupervised/images/'
images_n = ['image1.jpg', 'image2.jpg', 'image3.jpg', 'image4.jpg', 'image5.jpg']
images = []

for img_n in images_n:
    url = path.join(img_dir, img_n)
    img = parseUrl2Img(url)
    images.append(img)

# %%
for i in range(len(images)):
    plt.figure(i+1)
    plt.imshow(images[i])

# %%
for i in range(len(images)):
    plt.figure(i+1)
    plt.imshow(colorQuan(images[i], 3))
